# %% [markdown]
# ### List sorting

# %%
l1 = [
      {'name': 'Mohan', 'age': 33},
     {'name': 'Roopesh', 'age': 18},
      {'name': 'Vishwa', 'age': 32},
]
l1.sort()
print(l1)

# %% [markdown]
# ### Combining Two lists

# %%
l1 = ['Roopesh', 'Karunya']
l2 = ['Mohan', 'Vishwa', 'Rohit', 'Yashwant']
# Out:
# ['Roopesh', 'Karunya', ['Mohan', 'Vishwa', 'Rohit', 'Yashwant']]

# %% [markdown]
# ### List Comprehension

# %%
# I want the ditionaries where age = 18
l1 = [
      {'name': 'Mohan', 'age': 33},
     {'name': 'Roopesh', 'age': 18},
      {'name': 'Vishwa', 'age': 32},
]

# %% [markdown]
# ### Zip

# %%
# Make this a list of dictionaries (just like prev example)
names = ['Mohan', 'Roopesh', 'Vishwa']
ages = [33,18,32]

# %% [markdown]
# ### Dict flattening

# %%
# Flatten this to look like {"name": "Roopesh", "python": 5, ...}
expertise = {"name": "Roopesh", "expertise": {"area": "programming", "languages": {"python": 5, "java": 4} }  }

# %% [markdown]
# ### Dictionary reversal of values to keys and grouping

# %%
employees = [{"name": "Vishwa","role": "Manager" }, {"name": "Mohan","role": "Manager" }, {"name": "Roopesh","role": "Architect" }]

# Desired format:
# {"Manager": ['Vishwa', 'Mohan'], 'Architect':['Roopesh', 'Rohit']}
